# %%
# %pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.3.234-py3-none-any.whl.metadata (37 kB)
# ...
#   Using cached numpy-2.3.5-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached matplotlib-3.10.7-cp313-cp313-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pillow-12.0.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached scipy-1.16.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached torch-2.9.1-cp313-cp313-win_amd64.whl.metadata (30 kB)
# ...
#   Using cached torchvision-0.24.1-cp313-cp313-win_amd64.whl.metadata (5.9 kB)
# ...
#   Using cached polars-1.35.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...

# %%
# from ultralytics import YOLO

# data_file = 'rps-cls.yaml'

# import yaml

# # Print out the loaded YAML configuration
# with open(data_file, "r") as file:
#     config = yaml.safe_load(file)
#     print(config)  # Check the structure of the loaded config

# model = YOLO("yolov5s.yaml")

# model.train(
#     data=data_file,  # Path to the .yaml file
#     epochs=10,  # Number of training epochs
#     batch_size=1,  # Batch size (adjust based on your GPU memory)
#     img_size=200,  # Image size (adjust depending on your dataset)
#     device=0  # Set to -1 for CPU or 0 for GPU (if you have a CUDA-enabled GPU)
# )
# Out:
# {'path': 'Data', 'train': 'train', 'val': 'val', 'test': 'test', 'nc': 3, 'names': {0: 'rock', 1: 'paper', 2: 'scissors'}}
# Traceback (most recent call last):
#
#   File c:\Users\Isabella\Documents\School\Third_Year\AISE_3350_Cyber_Physical_Systems\Project\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[19], line 14
#     model.train(
#
#   File c:\Users\Isabella\Documents\School\Third_Year\AISE_3350_Cyber_Physical_Systems\Project\.venv\Lib\site-packages\ultralytics\engine\model.py:768 in train
#     self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#
#   File c:\Users\Isabella\Documents\School\Third_Year\AISE_3350_Cyber_Physical_Systems\Project\.venv\Lib\site-packages\ultralytics\models\yolo\detect\train.py:63 in __init__
#     super().__init__(cfg, overrides, _callbacks)
#
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-cls.pt")  # load an official model
# model = YOLO("path/to/best.pt")  # load a custom model

# Predict with the model
results = model("Data/train/paper/paper0001.png")  # predict on an image
# Out:
# image 1/1 c:\Users\Isabella\Documents\School\Third_Year\AISE_3350_Cyber_Physical_Systems\Project\Data\train\paper\paper0001.png: 224x224 green_mamba 0.14, pick 0.13, Band_Aid 0.13, nematode 0.05, vine_snake 0.03, 17.1ms
# Speed: 4.2ms preprocess, 17.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-cls.yaml")  # build a new model from YAML
# model = YOLO("yolo11n-cls.pt")  # load a pretrained model (recommended for training)
# model = YOLO("rps-cls.yaml").load("yolo11n-cls.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data="Data", epochs=10, imgsz=200)
# Out:
# YOLO11n-cls summary: 86 layers, 2,812,104 parameters, 2,812,104 gradients, 4.3 GFLOPs
# Ultralytics 8.3.234  Python-3.13.5 torch-2.9.1+cpu CPU (12th Gen Intel Core i5-1240P)
# ...
